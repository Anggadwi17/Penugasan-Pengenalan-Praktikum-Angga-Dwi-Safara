# %%
print("Nama : Angga Dwi Safara")#Kode ini perintah untuk mencetak nama
print("NIM : 2605060079")#Kode ini perintah untuk mencetak NIM
print("Tempat, Tanggal Lahir : Magelang, 17 Juli 2006")#Kode ini perintah untuk mencetak Tempat, Tanggal Lahir
print("Alamat : Jrebeng 012/004, Giriwetan, Grabag, Magelang")#Kode ini perintah untuk mencetak Alamat
print("Jenis Kelamin : Laki-laki")#Kode ini perintah untuk mencetak Jenis kelamin
print("Hobi : Mendaki Gunung dan Menyanyi")#Kode ini perintah untuk mencetak Hobi
# Out:
# Nama : Angga Dwi Safara
# NIM : 2605060079
# Tempat, Tanggal Lahir : Magelang, 17 Juli 2006
# Alamat : Jrebeng 012/004, Giriwetan, Grabag, Magelang
# Jenis Kelamin : Laki-laki
# Hobi : Mendaki Gunung dan Menyanyi
